# %%
def hasNumbers(inputString):
    for char in inputString:
        if char.isdigit()==True:
            return True

# %%
def MagicNumber(inputString):
    
    if hasNumbers(inputString):
        if line.__contains__(" = ")  and line.count(" = ")==1:   
            return
        if any(char==">" or "<" or "==" or "+=" or "+" or "-" for char in inputString)==True:
            print("Line {}: {}".format(cnt, "this line contain magic number is "))
            getNumber(line)
            return True
        else:
            return False

# %%
import re
def getNumber(string):
    try:
        found = re.search('-?[0-9]+.?[0-9]*', string).group()
        print(found)
    except AttributeError:
        pass

# %%
filepath = 'E:\\baraa.txt'
with open(filepath) as fp:
   line = fp.readline()
   cnt = 1
   while line:
       MagicNumber(line)
       line = fp.readline()
       cnt += 1
# Out:
# Line 1: this line contain magic number is
# -1.4
# Line 2: this line contain magic number is
# 125
# Line 3: this line contain magic number is
# 0
# Line 4: this line contain magic number is
# 5
