# %%
import re
def get_string(string):
    try:
        found = re.search('"(.+?)"|\'(.+?)\'', string).group(1)
        return found
    except AttributeError:
        pass

# %%
def hasQuotation(inputString):
    for char in inputString:
        x= line.find('"')
        if x > 0:
                return True

# %%
def MagicString(inputString):
    
    if hasQuotation(inputString)==True:
        if line.__contains__(" = ")  and line.count(" = ")==1:   
            return
        if any(char== "==" or "+" for char in inputString)==True:
            print("Line {}: {}".format(cnt, "this line contain magic string is "))
            print(get_string(line))
            return True
        else:
            return False

# %%
filepath = 'E:\\baraa2.txt'
with open(filepath) as fp:
    line = fp.readline()
    cnt = 1
    while line:
        MagicString(line)
        line = fp.readline()
        cnt += 1
# Out:
# Line 1: this line contain magic string is
# Unknown
# Line 2: this line contain magic string is
# Pass
# Line 3: this line contain magic string is
# Fail
